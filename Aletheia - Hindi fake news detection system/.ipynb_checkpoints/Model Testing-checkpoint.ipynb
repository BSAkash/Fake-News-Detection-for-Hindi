# %%
from gensim.models import Word2Vec
from sklearn.manifold import TSNE
import pandas as pd

from mlxtend.plotting import plot_confusion_matrix
import matplotlib.pyplot as plt
import csv 
from scipy.spatial import distance

import numpy as np

# %%
model = Word2Vec.load("word2vec.model")

# %%
len(model.wv)
# Out:
# 64334

# %%
vocab = list(model.wv.key_to_index)
X = model.wv[vocab]

# %%
tsne = TSNE(n_components=2)
X_tsne = tsne.fit_transform(X)

# %%
df = pd.DataFrame(X_tsne, index=vocab, columns=['x', 'y'])

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.scatter(df['x'], df['y'])

# %%
for word, pos in df.iterrows():
    ax.annotate(word, pos)

# %%
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.scatter(df['x'], df['y'])
for word, pos in df.iterrows():
    ax.annotate(word, pos)
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2325 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2361 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2350 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2360 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2352 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2351 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2341 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2349 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2332 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2357 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2337 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2354 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2344 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2327 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2319 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2340 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2342 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2346 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2335 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2326 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2348 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2310 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2309 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2311 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2320 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2313 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2312 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2330 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2358 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2347 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2331 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2333 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2336 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2343 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2395 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2359 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2328 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2398 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2338 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2323 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2396 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2321 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2339 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2314 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2711 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2716 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2736 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2724 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2397 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2728 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2965 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2969 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2992 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 3000 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2334 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2411 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2407 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2406 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2694 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2741 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2693 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2730 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2719 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2727 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2732 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2738 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2721 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2745 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2735 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2734 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2393 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2980 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2970 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2990 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2394 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2726 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2392 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2315 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2324 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2353 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2453 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2480 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 1746 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2317 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2472 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2438 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2478 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2470 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2384 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2598 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2596 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2468 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 1729 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2469 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2600 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2447 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2439 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2471 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2479 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2488 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2486 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2459 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2482 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2489 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2613 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2586 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2593 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2581 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2591 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2608 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2602 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2610 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2616 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2487 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2460 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2437 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2475 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2463 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2474 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2458 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2451 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2527 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2454 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2476 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2441 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2465 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2588 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2604 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 3125 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 3108 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 3126 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2477 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2617 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2567 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2329 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2455 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2409 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2742 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2744 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2696 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2464 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2467 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2536 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2539 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 22283 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 38450 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 37096 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2997 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2985 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 119808 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 119834 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 119852 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 119841 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 119854 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2345 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2994 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2535 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2534 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2457 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2541 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2356 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2466 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2408 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2415 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 3114 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 3122 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 3120 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 3116 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 3129 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 3118 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 3110 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 3128 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 3098 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 3112 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 3111 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 3095 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 3100 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 3103 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 3105 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 3093 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 3117 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 3119 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 3107 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2599 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2566 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2595 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2583 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2579 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2606 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2603 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2605 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2461 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2524 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2456 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 78217 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2587 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2565 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2410 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2414 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2675 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2652 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2568 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2614 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2582 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2951 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2984 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 2399 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 120298 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 120276 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 120293 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 120289 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 120284 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 120282 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 120294 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 120280 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 120295 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 120297 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 120306 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 120325 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 120322 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 120302 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 120313 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 120279 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 120290 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 120304 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 120316 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 120315 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 120321 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 119818 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 120049 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 120062 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 120052 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 120053 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 120042 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 120019 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 120046 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 120057 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 2448 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 2544 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 2545 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12540 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3374 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3350 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3375 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3368 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3364 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3376 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3381 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3359 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3377 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3349 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3454 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3382 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3380 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3384 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3452 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3365 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3363 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3336 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3356 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3353 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3379 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3370 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3383 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3373 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3334 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3378 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3453 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3354 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3351 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3361 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3333 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3337 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3451 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3367 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3226 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3248 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3228 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3243 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3240 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3256 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3250 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3236 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3253 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3247 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3221 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3244 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3231 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3233 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3205 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3242 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3215 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3235 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3246 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3238 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3223 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3208 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3224 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3245 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3251 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3257 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3239 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3255 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 3207 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 2462 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 2322 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
with open('Final_Vectors.csv', newline='') as f:
  reader = csv.reader(f)
  True_vector = next(reader)  # gets the first line
  False_vector = next(reader)

# %%
true_vector_floats = []
false_vector_floats = []


for item in True_vector:

    true_vector_floats.append(float(item))

for item in False_vector:

    false_vector_floats.append(float(item))

# %%
def documentvec(word2vec_model,summarywords):
    "This function Creates a document vector by taking the mean of word vectors of the words in the document"
    k=[]
    for i in range(len(summarywords)): 
        if summarywords[i] in word2vec_model.wv:#model.wv.vocab gives the entire word vocabulary 
            k.append(word2vec_model.wv[summarywords[i]])#of the generated model upon the given dataset
    return np.mean(k,axis=0)

# %%
    test_summary = "दरभंगा मेडिकल कॉलेज के माइक्रोबायोलॉजी विभाग में ट्रू नेट मशीन से कोरोना की जांच शुरू हो गई है। हालांकि सूत्रों के मुताबिक फिलहाल काफी कम संख्या में ट्रू नेट से जांच हो पा रही है। इधर नाम नहीं छापने की शर्त पर कई लोगों ने बताया कि कमरे में एसी नहीं रहने के कारण पीपीई किट पहनकर जांच करने में काफी परेशानी हो रही है। पीपीई किट पहनने व बदलने के लिए कमरा भी नहीं है। पेयजल की भी काफी किल्लत है। सुविधाओं के सिलसिले में जानकारी के लिए दरभंगा मेडिकल कॉलेज के प्राचार्य को फोन किया गया। हालांकि जरूरी मीटिंग में शामिल रहने की वजह से उनसे बात नहीं हो सकी"
    test_summary_words = test_summary.split(' ')
    corpus2 = []
    corpus2.append(test_summary_words)
    model.build_vocab(corpus2, update = True)
    model.train(corpus2, total_examples=2, epochs = 1)
    test_vector = documentvec(model,test_summary_words)
    true_class  = 1 - distance.cosine(test_vector,true_vector_floats)
    false_class  = 1 - distance.cosine(test_vector,false_vector_floats)
    if true_class > false_class:
        category = 1
    else:
        category = 0
        
print(category)
# Out:
# 1

# %%
len(model.wv)
# Out:
# 64399
